# %%
import MDeval as md
import pandas as pd

# %%
ConceptDF = pd.read_csv("../bedi/data/LTER/PIE__2005_EML_ConceptEvaluated.csv.gz")

# %%
ConceptDF
# Out:
#       Collection Dialect     Record                           Concept  \
# 0      PIE__2005     EML  101.5.xml                    Resource Title
# 1      PIE__2005     EML  101.5.xml   Resource Creation/Revision Date
# 2      PIE__2005     EML  101.5.xml                          Abstract
# 3      PIE__2005     EML  101.5.xml                  Metadata Contact
# 4      PIE__2005     EML  101.5.xml                  Resource Contact
# 5      PIE__2005     EML  101.5.xml                 Organization Name
# 6      PIE__2005     EML  101.5.xml                 Organization Name
# 7      PIE__2005     EML  101.5.xml                            Author
# 8      PIE__2005     EML  101.5.xml                  Publication Date
# 9      PIE__2005     EML  101.5.xml                         Publisher
# 10     PIE__2005     EML  101.5.xml                     Publisher URL
# 11     PIE__2005     EML  101.5.xml                  Publisher E-Mail
# 12     PIE__2005     EML  101.5.xml               Resource Identifier
# 13     PIE__2005     EML  101.5.xml             Southernmost Latitude
# 14     PIE__2005     EML  101.5.xml             Northernmost Latitude
# 15     PIE__2005     EML  101.5.xml             Westernmost Longitude
# 16     PIE__2005     EML  101.5.xml             Easternmost Longitude
# 17     PIE__2005     EML  101.5.xml                        Start Time
# 18     PIE__2005     EML  101.5.xml                          End Time
# 19     PIE__2005     EML  101.5.xml               Author / Originator
# 20     PIE__2005     EML  101.5.xml    Author / Originator Identifier
# 21     PIE__2005     EML  101.5.xml                      Bounding Box
# 22     PIE__2005     EML  101.5.xml                  Contributor Name
# 23     PIE__2005     EML  101.5.xml                   Resource Format
# 24     PIE__2005     EML  101.5.xml                            Rights
# 25     PIE__2005     EML  101.5.xml          Resource Use Constraints
# 26     PIE__2005     EML  101.5.xml               Distribution Format
# 27     PIE__2005     EML  101.5.xml                      Process Step
# 28     PIE__2005     EML  101.5.xml  Entity and Attribute Information
# 29     PIE__2005     EML  101.5.xml            Entity Type Definition
# ...          ...     ...        ...                               ...
# 13491  PIE__2005     EML  110.2.xml               Resource Identifier
# 13492  PIE__2005     EML  110.2.xml             Southernmost Latitude
# 13493  PIE__2005     EML  110.2.xml             Northernmost Latitude
# 13494  PIE__2005     EML  110.2.xml             Westernmost Longitude
# 13495  PIE__2005     EML  110.2.xml             Easternmost Longitude
# 13496  PIE__2005     EML  110.2.xml                  Vertical Minimum
# 13497  PIE__2005     EML  110.2.xml                  Vertical Maximum
# 13498  PIE__2005     EML  110.2.xml               Vertical Resolution
# 13499  PIE__2005     EML  110.2.xml               Author / Originator
# 13500  PIE__2005     EML  110.2.xml                      Bounding Box
# 13501  PIE__2005     EML  110.2.xml                  Contributor Name
# 13502  PIE__2005     EML  110.2.xml                  Contributor Name
# 13503  PIE__2005     EML  110.2.xml                            Rights
# 13504  PIE__2005     EML  110.2.xml          Resource Use Constraints
# 13505  PIE__2005     EML  110.2.xml                      Process Step
# 13506  PIE__2005     EML  110.2.xml                   Temporal Extent
# 13507  PIE__2005     EML  110.2.xml                  Resource Lineage
# 13508  PIE__2005     EML  110.2.xml              Resource Online Link
# 13509  PIE__2005     EML  110.2.xml                Resource Long Name
# 13510  PIE__2005     EML  110.2.xml                    Spatial Extent
# 13511  PIE__2005     EML  110.2.xml                      Project Name
# 13512  PIE__2005     EML  110.2.xml                  Contributor Role
# 13513  PIE__2005     EML  110.2.xml                  Contributor Role
# 13514  PIE__2005     EML  110.2.xml          Resource Identifier Type
# 13515  PIE__2005     EML  110.2.xml                           Keyword
# 13516  PIE__2005     EML  110.2.xml                           Keyword
# 13517  PIE__2005     EML  110.2.xml                           Keyword
# 13518  PIE__2005     EML  110.2.xml                           Keyword
# 13519  PIE__2005     EML  110.2.xml             Resource Distribution
# 13520  PIE__2005     EML  110.2.xml                       Maintenance
#
#                                                    XPath  \
# 0                                 /eml:eml/dataset/title
# 1                               /eml:eml/dataset/pubDate
# 2                              /eml:eml/dataset/abstract
# 3                      /eml:eml/dataset/metadataProvider
# 4                               /eml:eml/dataset/contact
# 5      /eml:eml/dataset/metadataProvider/organization...
# 6            /eml:eml/dataset/publisher/organizationName
# 7                               /eml:eml/dataset/creator
# 8                               /eml:eml/dataset/pubDate
# 9                             /eml:eml/dataset/publisher
# 10      /eml:eml/dataset/publisher/electronicMailAddress
# 11      /eml:eml/dataset/publisher/electronicMailAddress
# 12                                   /eml:eml/@packageId
# 13     /eml:eml/dataset/coverage/geographicCoverage/b...
# 14     /eml:eml/dataset/coverage/geographicCoverage/b...
# 15     /eml:eml/dataset/coverage/geographicCoverage/b...
# 16     /eml:eml/dataset/coverage/geographicCoverage/b...
# 17     /eml:eml/dataset/coverage/temporalCoverage/ran...
# 18     /eml:eml/dataset/coverage/temporalCoverage/ran...
# 19                              /eml:eml/dataset/creator
# 20                          /eml:eml/dataset/creator/@id
# 21     /eml:eml/dataset/coverage/geographicCoverage/b...
# 22                      /eml:eml/dataset/associatedParty
# 23        /eml:eml/dataset/dataTable/physical/dataFormat
# 24                   /eml:eml/dataset/intellectualRights
# 25                   /eml:eml/dataset/intellectualRights
# 26        /eml:eml/dataset/dataTable/physical/dataFormat
# 27                              /eml:eml/dataset/methods
# 28          /eml:eml/dataset/dataTable/entityDescription
# 29          /eml:eml/dataset/dataTable/entityDescription
# ...                                                  ...
# 13491                                /eml:eml/@packageId
# 13492  /eml:eml/dataset/coverage/geographicCoverage/b...
# 13493  /eml:eml/dataset/coverage/geographicCoverage/b...
# 13494  /eml:eml/dataset/coverage/geographicCoverage/b...
# 13495  /eml:eml/dataset/coverage/geographicCoverage/b...
# 13496  /eml:eml/dataset/coverage/geographicCoverage/b...
# 13497  /eml:eml/dataset/coverage/geographicCoverage/b...
# 13498  /eml:eml/dataset/coverage/geographicCoverage/b...
# 13499                           /eml:eml/dataset/creator
# 13500  /eml:eml/dataset/coverage/geographicCoverage/b...
# 13501                   /eml:eml/dataset/associatedParty
# 13502                   /eml:eml/dataset/associatedParty
# 13503                /eml:eml/dataset/intellectualRights
# 13504                /eml:eml/dataset/intellectualRights
# 13505                           /eml:eml/dataset/methods
# 13506         /eml:eml/dataset/coverage/temporalCoverage
# 13507                           /eml:eml/dataset/methods
# 13508           /eml:eml/dataset/distribution/online/url
# 13509                             /eml:eml/dataset/title
# 13510       /eml:eml/dataset/coverage/geographicCoverage
# 13511     /eml:eml/dataset/creator/electronicMailAddress
# 13512              /eml:eml/dataset/associatedParty/role
# 13513              /eml:eml/dataset/associatedParty/role
# 13514                                   /eml:eml/@system
# 13515                /eml:eml/dataset/keywordSet/keyword
# 13516                /eml:eml/dataset/keywordSet/keyword
# 13517                /eml:eml/dataset/keywordSet/keyword
# 13518                /eml:eml/dataset/keywordSet/keyword
# 13519                      /eml:eml/dataset/distribution
# 13520                       /eml:eml/dataset/maintenance
#
#                                                  Content
# 0              Parker River daily discharge, Byfield, MA
# 1                                                   2000
# 2      USGS gauged discharge from the Parker River at...
# 3      Plum Island Ecosystems LTER ProgramThe Ecosyst...
# 4      Data ManagerThe Ecosystems CenterMarine Biolog...
# 5                    Plum Island Ecosystems LTER Program
# 6                            Plum Island Ecosystems LTER
# 7      ChuckHopkinsonEcosystems CenterMBL7 MBL StWood...
# 8                                                   2000
# 9      Plum Island Ecosystems LTERThe Ecosystems Cent...
# 10                                        pie_im@mbl.edu
# 11                                        pie_im@mbl.edu
# 12                                    knb-lter-pie.101.5
# 13                                               42.7528
# 14                                               42.7528
# 15                                              -70.9461
# 16                                              -70.9461
# 17                                            1945-10-26
# 18                                            2011-01-26
# 19     ChuckHopkinsonEcosystems CenterMBL7 MBL StWood...
# 20                                                pers-1
# 21                        -70.9461-70.946142.752842.7528
# 22                     HapGarrittadditional investigator
# 23                                              1column,
# 24     Acceptance and utilization of PIE-LTER data re...
# 25     Acceptance and utilization of PIE-LTER data re...
# 26                                              1column,
# 27     Data was downloaded from USGS web site: http:/...
# 28             Parker River daily discharge, Byfield, MA
# 29             Parker River daily discharge, Byfield, MA
# ...                                                  ...
# 13491                                knb-lter-pie.0110.2
# 13492                                              42.50
# 13493                                              42.89
# 13494                                             -71.22
# 13495                                             -70.75
# 13496                                                  0
# 13497                                                175
# 13498                                              meter
# 13499  CharlesVorosmartyISEOSUniversity of New Hampsh...
# 13500                    -71.22-70.7542.8942.500175meter
# 13501             WilfredWollheimadditional investigator
# 13502               BrianPellerinadditional investigator
# 13503  Acceptance and utilization of PIE-LTER data re...
# 13504  Acceptance and utilization of PIE-LTER data re...
# 13505  YSI 6200 data sondes were deployed vertically ...
# 13506                                               2002
# 13507  YSI 6200 data sondes were deployed vertically ...
# 13508  http://ecosystems.mbl.edu/pie/data/WAT/WAT-YSI...
# 13509  Plum Island Ecosystem LTER -- Year 2002 Contin...
# 13510  Locations are in Massachusetts State Plane coo...
# 13511                         charles.vorosmarty@unh.edu
# 13512                            additional investigator
# 13513                            additional investigator
# 13514                                                knb
# 13515                                  water temperature
# 13516                                       conductivity
# 13517                                                 pH
# 13518                                  dissolved oxygen.
# 13519  http://ecosystems.mbl.edu/pie/data/WAT/WAT-YSI...
# 13520                                                NaN
#
# [13521 rows x 6 columns]

# %%
RecommendationDF = md.recommendationEval(ConceptDF, 'ECHO_Discovery')

# %%
RecommendationDF
# Out:
#       Collection Dialect     Record                      Concept  \
# 0      PIE__2005     EML  101.5.xml               Resource Title
# 2      PIE__2005     EML  101.5.xml                     Abstract
# 4      PIE__2005     EML  101.5.xml             Resource Contact
# 8      PIE__2005     EML  101.5.xml             Publication Date
# 12     PIE__2005     EML  101.5.xml          Resource Identifier
# 34     PIE__2005     EML  101.5.xml              Temporal Extent
# 37     PIE__2005     EML  101.5.xml           Resource Long Name
# 38     PIE__2005     EML  101.5.xml               Spatial Extent
# 42     PIE__2005     EML  101.5.xml                      Keyword
# 43     PIE__2005     EML  101.5.xml                      Keyword
# 44     PIE__2005     EML  101.5.xml                      Keyword
# 45     PIE__2005     EML  101.5.xml                      Keyword
# 46     PIE__2005     EML  101.5.xml                      Keyword
# 47     PIE__2005     EML  101.5.xml                      Keyword
# 48     PIE__2005     EML  101.5.xml                      Keyword
# 49     PIE__2005     EML  101.5.xml                      Keyword
# 50     PIE__2005     EML  101.5.xml                      Keyword
# 51     PIE__2005     EML  101.5.xml                      Keyword
# 56     PIE__2005     EML   25.3.xml               Resource Title
# 58     PIE__2005     EML   25.3.xml                     Abstract
# 60     PIE__2005     EML   25.3.xml             Resource Contact
# 64     PIE__2005     EML   25.3.xml             Publication Date
# 68     PIE__2005     EML   25.3.xml          Resource Identifier
# 120    PIE__2005     EML   25.3.xml              Temporal Extent
# 123    PIE__2005     EML   25.3.xml           Resource Long Name
# 124    PIE__2005     EML   25.3.xml               Spatial Extent
# 130    PIE__2005     EML   25.3.xml                      Keyword
# 131    PIE__2005     EML   25.3.xml                      Keyword
# 132    PIE__2005     EML   25.3.xml                      Keyword
# 137    PIE__2005     EML  119.4.xml               Resource Title
# ...          ...     ...        ...                          ...
# 13411  PIE__2005     EML   69.6.xml                      Keyword
# 13416  PIE__2005     EML   98.8.xml               Resource Title
# 13418  PIE__2005     EML   98.8.xml                     Abstract
# 13420  PIE__2005     EML   98.8.xml             Resource Contact
# 13425  PIE__2005     EML   98.8.xml             Publication Date
# 13429  PIE__2005     EML   98.8.xml          Resource Identifier
# 13445  PIE__2005     EML   98.8.xml  Resource Access Constraints
# 13457  PIE__2005     EML   98.8.xml              Temporal Extent
# 13460  PIE__2005     EML   98.8.xml           Resource Long Name
# 13461  PIE__2005     EML   98.8.xml               Spatial Extent
# 13467  PIE__2005     EML   98.8.xml                      Keyword
# 13468  PIE__2005     EML   98.8.xml                      Keyword
# 13469  PIE__2005     EML   98.8.xml                      Keyword
# 13470  PIE__2005     EML   98.8.xml                      Keyword
# 13471  PIE__2005     EML   98.8.xml                      Keyword
# 13472  PIE__2005     EML   98.8.xml                      Keyword
# 13473  PIE__2005     EML   98.8.xml                      Keyword
# 13474  PIE__2005     EML   98.8.xml                      Keyword
# 13475  PIE__2005     EML   98.8.xml                      Keyword
# 13480  PIE__2005     EML  110.2.xml               Resource Title
# 13481  PIE__2005     EML  110.2.xml                     Abstract
# 13483  PIE__2005     EML  110.2.xml             Resource Contact
# 13491  PIE__2005     EML  110.2.xml          Resource Identifier
# 13506  PIE__2005     EML  110.2.xml              Temporal Extent
# 13509  PIE__2005     EML  110.2.xml           Resource Long Name
# 13510  PIE__2005     EML  110.2.xml               Spatial Extent
# 13515  PIE__2005     EML  110.2.xml                      Keyword
# 13516  PIE__2005     EML  110.2.xml                      Keyword
# 13517  PIE__2005     EML  110.2.xml                      Keyword
# 13518  PIE__2005     EML  110.2.xml                      Keyword
#
#                                               XPath  \
# 0                            /eml:eml/dataset/title
# 2                         /eml:eml/dataset/abstract
# 4                          /eml:eml/dataset/contact
# 8                          /eml:eml/dataset/pubDate
# 12                              /eml:eml/@packageId
# 34       /eml:eml/dataset/coverage/temporalCoverage
# 37                           /eml:eml/dataset/title
# 38     /eml:eml/dataset/coverage/geographicCoverage
# 42              /eml:eml/dataset/keywordSet/keyword
# 43              /eml:eml/dataset/keywordSet/keyword
# 44              /eml:eml/dataset/keywordSet/keyword
# 45              /eml:eml/dataset/keywordSet/keyword
# 46              /eml:eml/dataset/keywordSet/keyword
# 47              /eml:eml/dataset/keywordSet/keyword
# 48              /eml:eml/dataset/keywordSet/keyword
# 49              /eml:eml/dataset/keywordSet/keyword
# 50              /eml:eml/dataset/keywordSet/keyword
# 51              /eml:eml/dataset/keywordSet/keyword
# 56                           /eml:eml/dataset/title
# 58                        /eml:eml/dataset/abstract
# 60                         /eml:eml/dataset/contact
# 64                         /eml:eml/dataset/pubDate
# 68                              /eml:eml/@packageId
# 120      /eml:eml/dataset/coverage/temporalCoverage
# 123                          /eml:eml/dataset/title
# 124    /eml:eml/dataset/coverage/geographicCoverage
# 130             /eml:eml/dataset/keywordSet/keyword
# 131             /eml:eml/dataset/keywordSet/keyword
# 132             /eml:eml/dataset/keywordSet/keyword
# 137                          /eml:eml/dataset/title
# ...                                             ...
# 13411           /eml:eml/dataset/keywordSet/keyword
# 13416                        /eml:eml/dataset/title
# 13418                     /eml:eml/dataset/abstract
# 13420                      /eml:eml/dataset/contact
# 13425                      /eml:eml/dataset/pubDate
# 13429                           /eml:eml/@packageId
# 13445                               /eml:eml/access
# 13457    /eml:eml/dataset/coverage/temporalCoverage
# 13460                        /eml:eml/dataset/title
# 13461  /eml:eml/dataset/coverage/geographicCoverage
# 13467           /eml:eml/dataset/keywordSet/keyword
# 13468           /eml:eml/dataset/keywordSet/keyword
# 13469           /eml:eml/dataset/keywordSet/keyword
# 13470           /eml:eml/dataset/keywordSet/keyword
# 13471           /eml:eml/dataset/keywordSet/keyword
# 13472           /eml:eml/dataset/keywordSet/keyword
# 13473           /eml:eml/dataset/keywordSet/keyword
# 13474           /eml:eml/dataset/keywordSet/keyword
# 13475           /eml:eml/dataset/keywordSet/keyword
# 13480                        /eml:eml/dataset/title
# 13481                     /eml:eml/dataset/abstract
# 13483                      /eml:eml/dataset/contact
# 13491                           /eml:eml/@packageId
# 13506    /eml:eml/dataset/coverage/temporalCoverage
# 13509                        /eml:eml/dataset/title
# 13510  /eml:eml/dataset/coverage/geographicCoverage
# 13515           /eml:eml/dataset/keywordSet/keyword
# 13516           /eml:eml/dataset/keywordSet/keyword
# 13517           /eml:eml/dataset/keywordSet/keyword
# 13518           /eml:eml/dataset/keywordSet/keyword
#
#                                                  Content
# 0              Parker River daily discharge, Byfield, MA
# 2      USGS gauged discharge from the Parker River at...
# 4      Data ManagerThe Ecosystems CenterMarine Biolog...
# 8                                                   2000
# 12                                    knb-lter-pie.101.5
# 34                                  1945-10-262011-01-26
# 37             Parker River daily discharge, Byfield, MA
# 38     Parker River at Byfield, Massachusetts; on lef...
# 42                                                  LTER
# 43                                                   PIE
# 44                                Plum Island Ecosystems
# 45                                         Massachusetts
# 46                                          Parker River
# 47                                           disturbance
# 48                                             discharge
# 49                                                stream
# 50                                                  flow
# 51                                                 river
# 56     Vegetation % cover data from quadrats along tr...
# 58     Vegetation % cover data from quadrats along tr...
# 60     Data ManagerThe Ecosystems CenterMarine Biolog...
# 64                                                  2002
# 68                                     knb-lter-pie.25.3
# 120                                 2000-08-072001-10-05
# 123    Vegetation % cover data from quadrats along tr...
# 124    Salt marsh that is hayed by Dan McHugh in Rowl...
# 130                                           salt marsh
# 131                                               haying
# 132                                           vegetation
# 137    Aboveground biomass of Typha sp. at Upper Park...
# ...                                                  ...
# 13411                                           pressure
# 13416         Ipswich River daily discharge, Ipswich, MA
# 13418  USGS gaged daily discharge from the Ipswich Ri...
# 13420  Data Manager The Ecosystems Center Marine Biol...
# 13425                                               2000
# 13429                                  knb-lter-pie.98.8
# 13445  uid=PIE,o=lter,dc=ecoinformatics,dc=org all pu...
# 13457                              1930-06-17 2013-10-22
# 13460         Ipswich River daily discharge, Ipswich, MA
# 13461  Ipswich River near Ipswich, MA; on left bank 2...
# 13467                                           PIE LTER
# 13468                             Plum Island Ecosystems
# 13469                                      Massachusetts
# 13470                                      Ipswich River
# 13471                                        disturbance
# 13472                                          discharge
# 13473                                             stream
# 13474                                               flow
# 13475                                              river
# 13480  Plum Island Ecosystem LTER -- Year 2002 Contin...
# 13481  Continuous measurements, every 15 minutes, wer...
# 13483  Data ManagerThe Ecosystems CenterMarine Biolog...
# 13491                                knb-lter-pie.0110.2
# 13506                                               2002
# 13509  Plum Island Ecosystem LTER -- Year 2002 Contin...
# 13510  Locations are in Massachusetts State Plane coo...
# 13515                                  water temperature
# 13516                                       conductivity
# 13517                                                 pH
# 13518                                  dissolved oxygen.
#
# [3399 rows x 6 columns]
